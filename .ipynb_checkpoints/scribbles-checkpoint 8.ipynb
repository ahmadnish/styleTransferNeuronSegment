# %%
import numpy

# plotting
import pylab

# to download data and unzip it
import os
import urllib.request
import zipfile

# to read the tiff files
import skimage.io
import skimage.filters
import skimage.morphology
import skimage.feature

# %%
plot_multiplier = 10
plotting = 'on'
# debugging: only use part of the training images

# we use part of the training images as ground truth    
split = 25
# how many training images do we load? 
# (affects speed and depends on training setup below, see "train_splits")

lim = 20

t = skimage.io.imread('NaturePaperDataUpl/ISBI2012/raw_train.tif')

# %%
t.shape
# Out:
# (30, 512, 512)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(t[0] , cmap = 'gray', )
plt.axis('off')
plt.savefig('./images/ISBI0.jpg', bbox_inches='tight', pad_inches = 0)

# %%
def display_image_in_actual_size(im_data):

    dpi = 80
    height, width, depth = im_data.shape

    # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi), height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image.
    ax.imshow(im_data, cmap='gray')

    plt.show()

# %%
display_image_in_actual_size(t[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-294-e5aac89c9de7> in <module>()
# ----> 1 display_image_in_actual_size(t[0])
#
# <ipython-input-293-c17f0c31de37> in display_image_in_actual_size(im_data)
#       2
#       3     dpi = 80
# ----> 4     height, width, depth = im_data.shape
#       5
#       6     # What size does the figure need to be in inches to fit the image?
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
pwd
# Out:
# '/Users/ahmadnish/Documents/Scientific Computing/AML/finalProject/AML2018'

# %%
plt.savefig('./images/ISBI0.jpg')

# %%
for i in range(t.shape[0]):

# %%
t = skimage.io.imread('output/stylized-raw_train.jpg-feathers.jpg-512.jpg')

# %%
import matplotlib.pyplot as plt

# %%
t.shape
# Out:
# (512, 512)

# %%
type(t)
# Out:
# numpy.ndarray

# %%
t = t / 255

# %%
t.max()
# Out:
# 1.0

# %%
t.min()
# Out:
# 0.0

# %%
plt.imshow(t, cmap='gray')

# %%
fig = plt.figure(figsize = (15, 15))
plt.imshow(t, cmap = 'gray')

# %%
numpy.linalg.norm(t, )
# Out:
# 73593.55499634462

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(t[1])

# %%
t[1].shape
# Out:
# (512, 512)

# %%
from PIL import Image

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
imsize = [512]

# %%
print("size: {}".format(imsize))
if len(imsize) > 1:
    loader = transforms.Compose([
        transforms.Resize((imsize[0], imsize[1])),  # scale imported image to squared image
        transforms.ToTensor()])  # transform it into a torch tensor
    imsize_name = "{}_{}".format(imsize[0], imsize[1])
else:
    loader = transforms.Compose([
        transforms.Resize((imsize[0], imsize[0])),  # scale imported image to squared image
        transforms.ToTensor()])  # transform it into a torch tensor
    imsize_name = "{}".format(imsize[0])
# Out:
# size: [512]

# %%
def image_loader(image_name):
    image = Image.open(image_name)
    # fake batch dimension required to fit network's input dimensions
    image = loader(image).unsqueeze(0)

    return image.to(device, torch.float)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
import torchvision.transforms as transforms
import torchvision.models as models
import numpy as np
import copy
import sys
import argparse
import scipy.misc
import imageio
import os
import time

# %%
content = image_loader("./images/raw_train.jpg")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-88c9e66f75df> in <module>
# ----> 1 content = image_loader("./images/raw_train.jpg")
#
# <ipython-input-18-cc1b75c655db> in image_loader(image_name)
#       4     image = loader(image).unsqueeze(0)
#       5
# ----> 6     return image.to(device, torch.float)
#
# NameError: name 'device' is not defined

# %%
import numpy as np

# %%
import skimage.io

# %%
plot_multiplier = 10
plotting = 'on'
# debugging: only use part of the training images

# we use part of the training images as ground truth    
split = 25
# how many training images do we load? 
# (affects speed and depends on training setup below, see "train_splits")

lim = 20

rawDsets = {
    'train' : skimage.io.imread('NaturePaperDataUpl/ISBI2012/raw_train.tif')[0:lim],
    'test' : skimage.io.imread('NaturePaperDataUpl/ISBI2012/raw_train.tif')[split:],
}

gtDsets = {
    'train' : skimage.io.imread('NaturePaperDataUpl/ISBI2012/groundtruth.tif')[0:lim],
    'test'  : skimage.io.imread('NaturePaperDataUpl/ISBI2012/groundtruth.tif')[split:]
}

computedData = {
    'train' : [{} for z in range(rawDsets['train'].shape[0])],
    'test'  : [{} for z in range(rawDsets['test'].shape[0])]
}

# %%
rawDsets['train'].shape
# Out:
# (20, 512, 512)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(rawDsets['train'][1])

# %%
pwd
# Out:
# '/Users/ahmadnish/Documents/Scientific Computing/AML/finalProject/AML2018'

# %%
temp = skimage.io.imread('output/out_style_texture/stylized-train0-style0-512.jpg')

# %%
temp.shape
# Out:
# (512, 512)

# %%
temp2 = skimage.io.imread('output/out_style_texture/stylized-train0-style1-512.jpg')

# %%
t = np.stack((temp, temp2))

# %%
t.shape
# Out:
# (512, 512, 2)

# %%
tt = np.reshape(t, (2, 512,512))

# %%
tt.shape
# Out:
# (2, 512, 512)

# %%
plt.imshow(t[:,:,1])

# %%
tt[1].shape
# Out:
# (512, 512)

# %%
images = [skimage.io.imread("output/out_style_texture/stylized-train{}-style{}-512-0.jpg".format(0,j)) for j in range(30)]

# %%
t = np.stack(images, axis = 0)

# %%
t.shape
# Out:
# (30, 512, 512)

# %%
figure = plt.figure(figsize= (15, 15))
plt.imshow(t[23],cmap = 'gray')

# %%
temp = t[1]

# %%
figure = plt.figure(figsize=(15,15))
plt.imshow(temp, 'gray')

# %%
temp = skimage.io.imread('images/raw_train.jpg')

# %%
temp = temp[1]
temp.shape
# Out:
# (512, 512)

# %%
figure = plt.figure(figsize=(15,15))
plt.imshow(temp, cmap = 'gray')

# %%
temp2 = skimage.filters.frangi(temp)

# %%
figure = plt.figure(figsize=(15,15))
plt.imshow(temp2)

# %%
np.max(temp2)
# Out:
# 8.696990236557254e-05

# %%
images = [skimage.io.imread("images/content/content{}.jpg".format(j)) for j in range(4)]
images[0].shape
# Out:
# (1067, 1600, 3)

# %%
from PIL import Image
image2 = Image.open("images/Barrel.jpg")

# %%
image2.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-142-a4dc484a5565> in <module>()
# ----> 1 image2.shape
#
# AttributeError: 'JpegImageFile' object has no attribute 'shape'

# %%
numpy
# Out:
# <module 'numpy' from '/anaconda/lib/python3.6/site-packages/numpy/__init__.py'>

# %%
np.sqrt(4)
# Out:
# 2.0

# %%
split = 24
lim = 12

rawDsets = {
    'train' : skimage.io.imread('NaturePaperDataUpl/ISBI2012/raw_train.tif')[0:lim],
    'test' : skimage.io.imread('NaturePaperDataUpl/ISBI2012/raw_train.tif')[split:],
}

print(rawDsets['train'].shape)
print(rawDsets['test'].shape)

train = []
styles = [2,6,8,9,12,15,20,21,28]

for i in range(lim):
    
    im = []
    
    im.append(rawDsets['train'][i])
    for j in styles:
        im.append(skimage.io.imread("output/out_style_texture/stylized-train{}-style{}-512.jpg".format(i,j)))
        
    im = np.stack(im, axis = 0)
    
    train.append(im)

# test = []
# for i in range(30 - split):
    
#     im = []
    
#     im.append(rawDsets['test'][i])
#     for j in styles:
#         im.append(skimage.io.imread("output/out_style_texture/stylized-train{}-style{}-512.jpg".format(i,j)))
    
#     im = np.stack(im, axis = 0)
    
#     test.append(im)

# testset = np.concatenate(test, axis = 0)  

trainset = np.concatenate(train, axis = 0)
rawDsets['train'] = trainset
print(rawDsets['train'].shape, rawDsets['test'].shape)
# Out:
# (12, 512, 512)
# (6, 512, 512)
# (120, 512, 512) (6, 512, 512)

# %%
gtDsets = {
    'train' : skimage.io.imread('NaturePaperDataUpl/ISBI2012/groundtruth.tif')[0:lim],
    'test'  : skimage.io.imread('NaturePaperDataUpl/ISBI2012/groundtruth.tif')[split:]
}

# %%
gtDsets['train'][1].shape
# Out:
# (512, 512)

# %%
gt_train = []
for i in range(lim):
    temp = [gtDsets['train'][i] for j in range(len(styles)+1)]
    temp = np.stack(temp, axis = 0)
    gt_train.append(temp)

print(gt_train[0].shape)
print(len(gt_train))

gtTrain = np.concatenate(gt_train, axis = 0)

gtTrain.shape
# Out:
# (10, 512, 512)
# 12
# (120, 512, 512)

# %%
temp = gtDsets['train']
temp.shape
# Out:
# (12, 512, 512)

# %%
plt.imshow(temp[2])

# %%
plt.imshow(temp[10])

# %%
perm = np.arange(120)
np.random.shuffle(perm)
perm
# Out:
# array([ 6,  8,  0, 11,  4, 10,  3,  5,  2,  9,  1,  7])

# %%
len(perm)
# Out:
# 12

# %%
temp3 = temp[perm]

# %%
plt.imshow(temp3[10])

# %%
1+1
# Out:
# 2
